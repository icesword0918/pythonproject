# %%
import matplotlib.pyplot as plt
import  numpy as np
# 让图表直接在jupyter notebook中展示出来
# %matplotlib inline
# 解决中文乱码问题
plt.rcParams["font.sans-serif"]='SimHei'
# 解决负号无法正常显示的问题
plt.rcParams["axes.unicode_minus"]=False
# 图表设置成矢量图格式显示
# %config InlineBackend.figure_format='svg'

# 用add_subplot函数建立坐标系
"""
# 建立画布
fig=plt.figure(figsize=(8,6))
# ax1=fig.add_subplot(1,1,1)

ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
"""
# 用plt.subplot2grid函数建立坐标
""" 
x=np.arange(6)
y=np.arange(6)
# 将图表的整个区域分成2行2列，且在（0，0）位置做成折线图
plt.subplot2grid((2,2),(0,0))
plt.plot(x,y)

# 将图表的整个区域分成2行2列，且在（0，0）位置做成柱形图
plt.subplot2grid((2,2),(0,1))
plt.bar(x,y)
"""
# 用plt.subplot函数建立坐标
"""
x=np.arange(6)
y=np.arange(6)
# 将图表的整个区域分成2行2列，且在第一各坐标系上做成折线图
plt.subplot(2,2,1)
plt.plot(x,y)
# 将图表的整个区域分成2行2列，且在第4各坐标系上做成柱形图
plt.subplot(2,2,4)
plt.bar(x,y)
"""
# 用plt.subplots函数建立坐标
"""
x=np.arange(6)
y=np.arange(6)
fig,axes=plt.subplots(2,2)
# 在[0，0]坐标系中绘制折线图
axes[0,0].plot(x,y)
# 在[1，1]坐标系中绘制柱状图
axes[1,1].bar(x,y)
"""
# 设置坐标轴
# 设置坐标轴的标题
fig=plt.figure(figsize=(8,6))
ax1=fig.add_subplot(1,1,1)
plt.xlabel("月份",labelpad=10)
plt.ylabel("注册量",labelpad=10)
# 设置坐标轴的刻度
# 设置x轴刻度
plt.xticks(np.arange(9),["1月份","2月份","3月份","4月份","5月份","6月份","7月份","8月份","9月份"])
# 设置y轴刻度
plt.yticks(np.arange(1000,7000,1000),["1000人","2000人","3000人","4000人","5000人","6000人"])
# 设置坐标轴的范围
plt.xlim(0,10)
plt.ylim(0,8000)
# 坐标轴的轴显示设置
# plt.axis("off")

# 其他图表格式的设置
# 网格线设置,axis=设置打开x或y的网格线,linestyle="dashed", linewidth=1 设置虚线
plt.grid(b="True",linestyle="dashed", linewidth=1)
# 设置图例
plt.plot(3,3,label="折线图")
plt.legend()
# 图标标题设置
plt.title(label="1-9月xxx公司注册用户数")
# 设置数据标签
# plt.text(5,1605,"极值点")
# 图表注释
plt.annotate("服务器宕机了",xy=(5,1605),xytext=(7,1605),arrowprops=dict(facecolor='black',arrowstyle='->'))
# Out:
# Text(6, 1605, '服务器宕机了')
